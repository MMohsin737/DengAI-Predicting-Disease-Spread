# %% [markdown]
# # <center>Tools & Techniques in Data Science</center>
#
# ## <center>Final Project</center>
#
# Muhammad Mohsin<br/>
# Roll Noumber: 18101138

# %% [markdown]
# First things To Do:-<br/>
# - Import Dataset.
# - Check if any null values are there or not.

# %%
# Importing Classes
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# <br/><br/>
# - Importing dataset

# %%
df = pd.read_csv(r'C:\Users\mmohs\Desktop\Project Tools & Techniques\dengue_train.csv')
df_test = pd.read_csv(r'C:\Users\mmohs\Desktop\Project Tools & Techniques\dengue_features_test.csv')

# %%
 df.head()
# Out:
#   city  year  weekofyear week_start_date   ndvi_ne   ndvi_nw   ndvi_se  \
# 0   sj  1990          18      1990/04/30  0.122600  0.103725  0.198483
# 1   sj  1990          19      1990/05/07  0.169900  0.142175  0.162357
# 2   sj  1990          20      1990/05/14  0.032250  0.172967  0.157200
# 3   sj  1990          21      1990/05/21  0.128633  0.245067  0.227557
# 4   sj  1990          22      1990/05/28  0.196200  0.262200  0.251200
#
#     ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  ...  \
# 0  0.177617                 12.42             297.572857  ...
# 1  0.155486                 22.82             298.211429  ...
# 2  0.170843                 34.54             298.781429  ...
# 3  0.235886                 15.36             298.987143  ...
# 4  0.247340                  7.52             299.518571  ...
#
#    reanalysis_relative_humidity_percent  reanalysis_sat_precip_amt_mm  \
# 0                             73.365714                         12.42
# ...

# %% [markdown]
# <br/><br/>
# - Checking if any null values exist in dataset.

# %%
df.isnull().any().tolist()
# Out:
# [False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  False]

# %%
df_test.isnull().any().tolist()
# Out:
# [False,
#  False,
#  False,
#  False,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True,
#  True]

# %%
#df = df.dropna()
#df_test = df.dropna()
#df['ndvi_ne'].fillna((df['ndvi_ne'].mean()), inplace = True)
#df['ndvi_nw'].fillna((df['ndvi_nw'].mean()), inplace = True)
#df['ndvi_se'].fillna((df['ndvi_se'].mean()), inplace = True)
#df['ndvi_sw'].fillna((df['ndvi_sw'].mean()), inplace = True)
#df['precipitation_amt_mm'].fillna((df['precipitation_amt_mm'].mean()), inplace = True)
#df['reanalysis_air_temp_k'].fillna((df['reanalysis_air_temp_k'].mean()), inplace = True)
#df['reanalysis_avg_temp_k'].fillna((df['reanalysis_avg_temp_k'].mean()), inplace = True)
#df['reanalysis_dew_point_temp_k'].fillna((df['reanalysis_dew_point_temp_k'].mean()), inplace = True)
#df['reanalysis_max_air_temp_k'].fillna((df['reanalysis_max_air_temp_k'].mean()), inplace = True)
#df['reanalysis_min_air_temp_k'].fillna((df['reanalysis_min_air_temp_k'].mean()), inplace = True)
#df['reanalysis_precip_amt_kg_per_m2'].fillna((df['reanalysis_precip_amt_kg_per_m2'].mean()), inplace = True)
#df['reanalysis_relative_humidity_percent'].fillna((df['reanalysis_relative_humidity_percent'].mean()), inplace = True)
#df['reanalysis_sat_precip_amt_mm'].fillna((df['reanalysis_sat_precip_amt_mm'].mean()), inplace = True)
#df['reanalysis_specific_humidity_g_per_kg'].fillna((df['reanalysis_specific_humidity_g_per_kg'].mean()),inplace = True)
#df['reanalysis_tdtr_k'].fillna((df['reanalysis_tdtr_k'].mean()), inplace = True)
#df['station_avg_temp_c'].fillna((df['station_avg_temp_c'].mean()), inplace = True)
#df['station_diur_temp_rng_c'].fillna((df['station_diur_temp_rng_c'].mean()), inplace = True)
#df['station_max_temp_c'].fillna((df['station_max_temp_c'].mean()), inplace = True)
#df['station_min_temp_c'].fillna((df['station_min_temp_c'].mean()), inplace = True)
#df['station_precip_mm'].fillna((df['station_precip_mm'].mean()), inplace = True)
#df['total_cases'].fillna((df['total_cases'].mean()), inplace = True)

# %%
#df_test['ndvi_ne'].fillna((df_test['ndvi_ne'].mean()), inplace = True)
#df_test['ndvi_nw'].fillna((df_test['ndvi_nw'].mean()), inplace = True)
#df_test['ndvi_se'].fillna((df_test['ndvi_se'].mean()), inplace = True)
#df_test['ndvi_sw'].fillna((df_test['ndvi_sw'].mean()), inplace = True)
#df_test['precipitation_amt_mm'].fillna((df_test['precipitation_amt_mm'].mean()), inplace = True)
#df_test['reanalysis_air_temp_k'].fillna((df_test['reanalysis_air_temp_k'].mean()), inplace = True)
#df_test['reanalysis_avg_temp_k'].fillna((df_test['reanalysis_avg_temp_k'].mean()), inplace = True)
#df_test['reanalysis_dew_point_temp_k'].fillna((df_test['reanalysis_dew_point_temp_k'].mean()), inplace = True)
#df_test['reanalysis_max_air_temp_k'].fillna((df_test['reanalysis_max_air_temp_k'].mean()), inplace = True)
#df_test['reanalysis_min_air_temp_k'].fillna((df_test['reanalysis_min_air_temp_k'].mean()), inplace = True)
#df_test['reanalysis_precip_amt_kg_per_m2'].fillna((df_test['reanalysis_precip_amt_kg_per_m2'].mean()), inplace = True)
#df_test['reanalysis_relative_humidity_percent'].fillna((df_test['reanalysis_relative_humidity_percent'].mean()), inplace = True)
#df_test['reanalysis_sat_precip_amt_mm'].fillna((df_test['reanalysis_sat_precip_amt_mm'].mean()), inplace = True)
#df_test['reanalysis_specific_humidity_g_per_kg'].fillna((df_test['reanalysis_specific_humidity_g_per_kg'].mean()), inplace = True)
#df_test['reanalysis_tdtr_k'].fillna((df_test['reanalysis_tdtr_k'].mean()), inplace = True)
#df_test['station_avg_temp_c'].fillna((df_test['station_avg_temp_c'].mean()), inplace = True)
#df_test['station_diur_temp_rng_c'].fillna((df_test['station_diur_temp_rng_c'].mean()), inplace = True)
#df_test['station_max_temp_c'].fillna((df_test['station_max_temp_c'].mean()), inplace = True)
#df_test['station_min_temp_c'].fillna((df_test['station_min_temp_c'].mean()), inplace = True)
#df_test['station_precip_mm'].fillna((df_test['station_precip_mm'].mean()), inplace = True)

# %% [markdown]
# Checking how much values are skwed from the center and than adding null values either with mean or median to bring data close to center.

# %%
plt.rc("font", size=13)
plt.figure(figsize=(20,50))
alpha=0.6

#--------------------------------------------------#

ax1 = plt.subplot2grid((10,2), (0,0))
df.ndvi_ne.plot(kind="kde",alpha=alpha)
ax1.set_xlabel("ndvi_ne")

ax2 = plt.subplot2grid((10,2),(0,1))
df.ndvi_nw.plot(kind="kde",alpha=alpha)
ax2.set_xlabel("ndvi_nw")


ax3 = plt.subplot2grid((10,2),(1,0))
df.ndvi_se.plot(kind="kde",alpha=alpha)
ax3.set_xlabel("ndvi_se")

ax4 = plt.subplot2grid((10,2),(1,1))
df.ndvi_sw.plot(kind="kde",alpha=alpha)
ax4.set_xlabel("ndvi_sw")


ax5 = plt.subplot2grid((10,2),(2,0))
df.precipitation_amt_mm.plot(kind="kde",alpha=alpha)
ax5.set_xlabel("precipitation_amt_mm")

ax6 = plt.subplot2grid((10,2),(2,1))
df.reanalysis_air_temp_k.plot(kind="kde",alpha=alpha)
ax6.set_xlabel("reanalysis_air_temp_k")


ax7 = plt.subplot2grid((10,2),(3,0))
df.reanalysis_avg_temp_k.plot(kind="kde",alpha=alpha)
ax7.set_xlabel("reanalysis_avg_temp_k")

ax8 = plt.subplot2grid((10,2),(3,1))
df.reanalysis_dew_point_temp_k.plot(kind="kde",alpha=alpha)
ax8.set_xlabel("reanalysis_dew_point_temp_k")


ax9 = plt.subplot2grid((10,2),(4,0))
df.reanalysis_max_air_temp_k.plot(kind="kde",alpha=alpha)
ax9.set_xlabel("reanalysis_max_air_temp_k")

ax10 = plt.subplot2grid((10,2),(4,1))
df.reanalysis_min_air_temp_k.plot(kind="kde",alpha=alpha)
ax10.set_xlabel("reanalysis_min_air_temp_k")


ax11 = plt.subplot2grid((10,2),(5,0))
df.reanalysis_precip_amt_kg_per_m2.plot(kind="kde",alpha=alpha)
ax11.set_xlabel("reanalysis_precip_amt_kg_per_m2")

ax12 = plt.subplot2grid((10,2),(5,1))
df.reanalysis_relative_humidity_percent.plot(kind="kde",alpha=alpha)
ax12.set_xlabel("reanalysis_relative_humidity_percent")


ax13 = plt.subplot2grid((10,2),(6,0))
df.reanalysis_sat_precip_amt_mm.plot(kind="kde",alpha=alpha)
ax13.set_xlabel("reanalysis_sat_precip_amt_mm")

ax14 = plt.subplot2grid((10,2),(6,1))
df.reanalysis_specific_humidity_g_per_kg.plot(kind="kde",alpha=alpha)
ax14.set_xlabel("reanalysis_specific_humidity_g_per_kg")


ax15 = plt.subplot2grid((10,2),(7,0))
df.reanalysis_tdtr_k.plot(kind="kde",alpha=alpha)
ax15.set_xlabel("reanalysis_tdtr_k")

ax16 = plt.subplot2grid((10,2),(7,1))
df.station_avg_temp_c.plot(kind="kde",alpha=alpha)
ax16.set_xlabel("station_avg_temp_c")


ax17 = plt.subplot2grid((10,2),(8,0))
df.station_diur_temp_rng_c.plot(kind="kde",alpha=alpha)
ax17.set_xlabel("station_diur_temp_rng_c")

ax18 = plt.subplot2grid((10,2),(8,1))
df.station_max_temp_c.plot(kind="kde",alpha=alpha)
ax18.set_xlabel("station_max_temp_c")


ax19 = plt.subplot2grid((10,2),(9,0))
df.station_min_temp_c.plot(kind="kde",alpha=alpha)
ax19.set_xlabel("station_min_temp_c")

ax20 = plt.subplot2grid((10,2),(9,1))
df.station_precip_mm.plot(kind="kde",alpha=alpha)
ax20.set_xlabel("station_precip_mm")
# Out:
# Text(0.5, 0, 'station_precip_mm')

# %% [markdown]
# Replacing all those null values in rows with mean or median of that row

# %%
for column in df.columns:
    if column in ['ndvi_ne','precipitation_amt_mm','reanalysis_air_temp_k','reanalysis_dew_point_temp_k',
                  'reanalysis_max_air_temp_k','reanalysis_min_air_temp_k','reanalysis_relative_humidity_percent',
                  'reanalysis_sat_precip_amt_mm','reanalysis_specific_humidity_g_per_kg','reanalysis_tdtr_k',
                  'station_avg_temp_c','station_diur_temp_rng_c','station_min_temp_c']:
        df[column].fillna(df[column].median(),inplace=True)
    elif column in ['ndvi_nw','ndvi_se','ndvi_sw','reanalysis_avg_temp_k','reanalysis_precip_amt_kg_per_m2',
                    'station_max_temp_c','station_precip_mm']:
        df[column].fillna(df[column].mean(),inplace=True)
        

for column in df_test.columns:
    if column in ['ndvi_ne','precipitation_amt_mm','reanalysis_air_temp_k','reanalysis_dew_point_temp_k',
                  'reanalysis_max_air_temp_k','reanalysis_min_air_temp_k','reanalysis_relative_humidity_percent',
                  'reanalysis_sat_precip_amt_mm','reanalysis_specific_humidity_g_per_kg','reanalysis_tdtr_k',
                  'station_avg_temp_c','station_diur_temp_rng_c','station_min_temp_c']:
        df_test[column].fillna(df_test[column].median(),inplace=True)
    elif column in ['ndvi_nw','ndvi_se','ndvi_sw','reanalysis_avg_temp_k','reanalysis_precip_amt_kg_per_m2',
                    'station_max_temp_c','station_precip_mm']:
        df_test[column].fillna(df_test[column].mean(),inplace=True)

# %%
df.describe()
# Out:
#               year   weekofyear      ndvi_ne      ndvi_nw      ndvi_se  \
# count  1456.000000  1456.000000  1456.000000  1456.000000  1456.000000
# mean   2001.031593    26.503434     0.140498     0.130553     0.203783
# std       5.408314    15.019437     0.130908     0.117835     0.073299
# min    1990.000000     1.000000    -0.406250    -0.456100    -0.015533
# 25%    1997.000000    13.750000     0.055625     0.051367     0.155625
# 50%    2002.000000    26.500000     0.128817     0.128067     0.196998
# 75%    2005.000000    39.250000     0.229292     0.212325     0.247021
# max    2010.000000    53.000000     0.508357     0.454429     0.538314
#
#            ndvi_sw  precipitation_amt_mm  reanalysis_air_temp_k  \
# count  1456.000000           1456.000000            1456.000000
# mean      0.202305             45.694135             298.701472
# std       0.083266             43.525407               1.357737
# min      -0.063457              0.000000             294.635714
# ...

# %% [markdown]
# Playing around with data (Feature Engineering & Feature Reduction)

# %%
#from datetime import datetime
#seasons = [0,0,1,1,1,2,2,2,3,3,3,0]
#df["seasons"] = df["week_start_date"].apply(lambda x : seasons[datetime.strptime(x, "%Y-%m-%d").month-1])
#df_test["seasons"] = df_test["week_start_date"].apply(lambda x : seasons[datetime.strptime(x, "%Y-%m-%d").month-1])

df = df.drop(['city', 'year', 'weekofyear', 'week_start_date'], 1)

df_test = df_test.drop(['city', 'year', 'weekofyear', 'week_start_date'], 1)


#df["city"][df["city"] == "sj"] = 1
#df["city"][df["city"] == "iq"] = 0

#df_test["city"][df_test["city"] == "sj"] = 1
#df_test["city"][df_test["city"] == "iq"] = 0

# %% [markdown]
# Separating feautres from tags

# %%
#df.city = den_test_df.city.astype("float64")
#df.year = den_test_df.year.astype("float64")
#df.weekofyear = den_test_df.weekofyear.astype("float64")
#df.seasons = den_test_df.seasons.astype("float64")

X = df.drop('total_cases', 1)
y = df['total_cases']

#X.head()
#y.head()

# %% [markdown]
# Spliting Train and Test Data Set

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %% [markdown]
# Creating into Model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import GridSearchCV

parameters = {'fit_intercept' : [True, False], 'normalize' : [True, False], 'n_jobs':[1, -1]}
reg = LinearRegression(fit_intercept=True, normalize=True)
clf = GridSearchCV(reg, parameters, cv=5)

# %% [markdown]
# Training the Model

# %%
clf.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'fit_intercept': [True, False], 'normalize': [True, False], 'n_jobs': [1, -1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
y_pridected = clf.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pridected)
# Out:
# 1518.8216661445515

# %%
clf.fit(X_test, y_test)
# Out:
# c:\users\mmohs\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_search.py:841: DeprecationWarning: The default of the `iid` parameter will change from True to False in version 0.22 and will be removed in 0.24. This will change numeric results when test-set sizes are unequal.
#   DeprecationWarning)
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=True),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'fit_intercept': [True, False], 'normalize': [True, False], 'n_jobs': [1, -1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_test, y_pridected)
# Out:
# 1518.8216661445515

# %%
from sklearn.metrics import r2_score
r2_score(y_test, y_pridected)
# Out:
# 0.12434418762918409

# %%
y_pridected = clf.predict(df_test)

# %% [markdown]
# Preparing final file for submission.

# %%
df_test_Final = pd.read_csv(r'C:\Users\mmohs\Desktop\Project Tools & Techniques\dengue_features_test.csv')

# %%
#y_pridected.to_csv(,index=False)

Data_Predicted = pd.read_csv(r'C:\Users\mmohs\Desktop\Project Tools & Techniques\dengue_features_test.csv',usecols=["city","year","weekofyear"])
Data_Predicted['total_cases'] = round(pd.Series(y_pridected))
Data_Predicted.head()
# Out:
#   city  year  weekofyear  total_cases
# 0   sj  2008          18         28.0
# 1   sj  2008          19         22.0
# 2   sj  2008          20         30.0
# 3   sj  2008          21         35.0
# 4   sj  2008          22         31.0

# %%
Data_Predicted.to_csv(r'C:\Users\mmohs\Desktop\Final_Output.csv',index=False)
